# %% [markdown]
# # Load data and packages

# %%
import pandas as pd
import numpy as np
import os

# %%
import pickle
import joblib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")

# For open the mlflow ui: mlflow ui --backend-store-uri sqlite:///mlflow.db
# Out:
# <Experiment: artifact_location=('file:///c:/Users/jhorea/OneDrive - Ecopetrol '
#  'S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/1'), creation_time=1716771880869, experiment_id='1', last_update_time=1716771880869, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
mlflow.get_artifact_uri()
# Out:
# 'file:///c:/Users/jhorea/OneDrive - Ecopetrol S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/1/6a05b9a3007a4b6a834b068da2b58aa8/artifacts'

# %% [markdown]
# # Relevant functions

# %%
def read_clean_data(data_link):
    data = pd.read_parquet(data_link)
    data['duration'] = data.tpep_dropoff_datetime - data.tpep_pickup_datetime
    data['duration'] = data['duration'].apply(lambda x: round(x.total_seconds()/60,4))
    data = data[(data["duration"]>=1) & ((data["duration"]<=60))]
    data['PULocationID']=data['PULocationID'].astype(str)
    data['DOLocationID']=data['DOLocationID'].astype(str)

    return data[['PULocationID','DOLocationID','duration']]

# %%
def create_train_and_val_data(encoder,data_train,data_val,input_columns,target):
    
    encoder.fit(data_train[input_columns])
    column_names=encoder.get_feature_names_out()

    # print(data_train[input_columns])
    # print("--")
    # print(column_names)

    X_train = pd.DataFrame(encoder.transform(data_train[input_columns]),columns=column_names)
    X_val = pd.DataFrame(encoder.transform(data_val[input_columns]),columns=column_names)

    y_train = data_train[target].values
    y_val = data_val[target].values

    return X_train,X_val,y_train,y_val

# %%
def val_data_v2(X_val,y_val):
    y_val = pd.Series(y_val)
    row_sum = X_val.sum(axis=1)
    id_obs = X_val[row_sum == 1].index

    X_val_2 = X_val[row_sum == 2]

    #  To gather the y_val taking in consideration only the valid observations
    mask=np.where(y_val.index.isin(id_obs),False,True)
    y_val_2 = y_val[mask]

    return X_val_2,y_val_2

# %% [markdown]
# # Pre-homework

# %% [markdown]
# ## 0.1 - Prepare the data

# %%
df_january = read_clean_data('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')
df_february = read_clean_data('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')

# %%
encoder = OneHotEncoder(sparse_output=False,handle_unknown='ignore')
X_train,X_val,y_train,y_val = create_train_and_val_data(encoder,df_january,df_february,['PULocationID','DOLocationID'],'duration')

# %%
X_val_2,y_val_2 = val_data_v2(X_val, y_val)

# %%
del df_january
del df_february
del encoder

# %%
model_lasso=Lasso(alpha=0.01)
model_lasso.fit(X_train,y_train)

# Save the model
joblib.dump(model_lasso, 'models/lasso_model.joblib')

del model_lasso

# %% [markdown]
# ## 0.2 - Example of using mlflow

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "Jhonattan")

    mlflow.log_param("train-data-path", 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet')
    mlflow.log_param("valid-data-path", 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet')

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    model = Lasso(alpha)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    # mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## 0.3 - Example of using hyperopt and autolog

# %%
import xgboost
from hyperopt import fmin, tpe, hp, Trials

# %%
def func_objetivo(params):
    with mlflow.start_run():
        mlflow.set_tag("developer", "Jhonattan")
        mlflow.set_tag("model", "xgboost_2wave")
        mlflow.log_params(params) #Not necessary when autolog enabled

        model = xgboost.XGBRegressor(**params)
        print("train start")
        model.fit(X_train,y_train, eval_set=[(X_train, y_train)])
        print("train finish")

        y_pred = model.predict(X_val_2)
        print("predict finish")
        error = root_mean_squared_error(y_pred,y_val_2)
        mlflow.log_metric("rmse",error)
        
        return error

# %%
mlflow.xgboost.autolog(disable=True) #Conflicted with hyperopt or similar and dont allow the training process to finish

espacio = {
    'n_estimators': hp.choice('n_estimators', range(150, 300)),
    'max_depth': hp.choice('max_depth', range(6, 15)),
    'learning_rate': hp.uniform('learning_rate', 0.1, 0.8),
    'subsample': hp.uniform('subsample', 0.6, 1.0),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.6, 1.0),
    'random_state': 40,
    'n_jobs': 12,
    'eval_metric' : root_mean_squared_error,
    'early_stopping_rounds' : 30,
}

trials_ = Trials()

best_estimator = fmin(fn=func_objetivo, space=espacio, algo=tpe.suggest, max_evals=10, trials=trials_)
# Out:
# train start
# [0]	validation_0-rmse:8.86982	validation_0-root_mean_squared_error:8.86982
# [1]	validation_0-rmse:8.54673	validation_0-root_mean_squared_error:8.54673
# [2]	validation_0-rmse:8.11128	validation_0-root_mean_squared_error:8.11128
# [3]	validation_0-rmse:7.84284	validation_0-root_mean_squared_error:7.84284
# [4]	validation_0-rmse:7.77729	validation_0-root_mean_squared_error:7.77729
# [5]	validation_0-rmse:7.70128	validation_0-root_mean_squared_error:7.70127
# [6]	validation_0-rmse:7.64288	validation_0-root_mean_squared_error:7.64288
# [7]	validation_0-rmse:7.58196	validation_0-root_mean_squared_error:7.58196
# [8]	validation_0-rmse:7.52681	validation_0-root_mean_squared_error:7.52681
# [9]	validation_0-rmse:7.48385	validation_0-root_mean_squared_error:7.48385
# [10]	validation_0-rmse:7.43998	validation_0-root_mean_squared_error:7.43998
# [11]	validation_0-rmse:7.41535	validation_0-root_mean_squared_error:7.41535
# [12]	validation_0-rmse:7.35659	validation_0-root_mean_squared_error:7.35659
# [13]	validation_0-rmse:7.32893	validation_0-root_mean_squared_error:7.32893
# [14]	validation_0-rmse:7.30823	validation_0-root_mean_squared_error:7.30823
# [15]	validation_0-rmse:7.29085	validation_0-root_mean_squared_error:7.29085
# [16]	validation_0-rmse:7.26620	validation_0-root_mean_squared_error:7.26620
# [17]	validation_0-rmse:7.23653	validation_0-root_mean_squared_error:7.23654
# [18]	validation_0-rmse:7.21559	validation_0-root_mean_squared_error:7.21559
# [19]	validation_0-rmse:7.20203	validation_0-root_mean_squared_error:7.20204
# [20]	validation_0-rmse:7.19062	validation_0-root_mean_squared_error:7.19062
# [21]	validation_0-rmse:7.17251	validation_0-root_mean_squared_error:7.17251
# [22]	validation_0-rmse:7.14880	validation_0-root_mean_squared_error:7.14880
# [23]	validation_0-rmse:7.13457	validation_0-root_mean_squared_error:7.13457
# [24]	validation_0-rmse:7.10654	validation_0-root_mean_squared_error:7.10654
# [25]	validation_0-rmse:7.08575	validation_0-root_mean_squared_error:7.08575
# [26]	validation_0-rmse:7.07405	validation_0-root_mean_squared_error:7.07405
# [27]	validation_0-rmse:7.05581	validation_0-root_mean_squared_error:7.05581
# [28]	validation_0-rmse:7.04462	validation_0-root_mean_squared_error:7.04462
# [29]	validation_0-rmse:7.03727	validation_0-root_mean_squared_error:7.03726
# [30]	validation_0-rmse:7.01354	validation_0-root_mean_squared_error:7.01354
# [31]	validation_0-rmse:6.99168	validation_0-root_mean_squared_error:6.99168
# [32]	validation_0-rmse:6.98542	validation_0-root_mean_squared_error:6.98542
# [33]	validation_0-rmse:6.97636	validation_0-root_mean_squared_error:6.97636
# [34]	validation_0-rmse:6.96208	validation_0-root_mean_squared_error:6.96208
# [35]	validation_0-rmse:6.94942	validation_0-root_mean_squared_error:6.94942
# [36]	validation_0-rmse:6.92846	validation_0-root_mean_squared_error:6.92845
# [37]	validation_0-rmse:6.91818	validation_0-root_mean_squared_error:6.91818
# [38]	validation_0-rmse:6.90364	validation_0-root_mean_squared_error:6.90363
# [39]	validation_0-rmse:6.89481	validation_0-root_mean_squared_error:6.89481
# [40]	validation_0-rmse:6.88854	validation_0-root_mean_squared_error:6.88854
# [41]	validation_0-rmse:6.88012	validation_0-root_mean_squared_error:6.88012
# [42]	validation_0-rmse:6.87613	validation_0-root_mean_squared_error:6.87613
# [43]	validation_0-rmse:6.87073	validation_0-root_mean_squared_error:6.87073
# [44]	validation_0-rmse:6.86477	validation_0-root_mean_squared_error:6.86478
# [45]	validation_0-rmse:6.86043	validation_0-root_mean_squared_error:6.86043
# [46]	validation_0-rmse:6.85225	validation_0-root_mean_squared_error:6.85225
# [47]	validation_0-rmse:6.84596	validation_0-root_mean_squared_error:6.84596
# [48]	validation_0-rmse:6.83890	validation_0-root_mean_squared_error:6.83890
# [49]	validation_0-rmse:6.83568	validation_0-root_mean_squared_error:6.83568
# [50]	validation_0-rmse:6.82742	validation_0-root_mean_squared_error:6.82742
# [51]	validation_0-rmse:6.79591	validation_0-root_mean_squared_error:6.79591
# [52]	validation_0-rmse:6.76740	validation_0-root_mean_squared_error:6.76740
# [53]	validation_0-rmse:6.75316	validation_0-root_mean_squared_error:6.75316
# [54]	validation_0-rmse:6.72948	validation_0-root_mean_squared_error:6.72947
# [55]	validation_0-rmse:6.69437	validation_0-root_mean_squared_error:6.69437
# [56]	validation_0-rmse:6.69185	validation_0-root_mean_squared_error:6.69185
# [57]	validation_0-rmse:6.68646	validation_0-root_mean_squared_error:6.68646
# [58]	validation_0-rmse:6.68394	validation_0-root_mean_squared_error:6.68395
# [59]	validation_0-rmse:6.67880	validation_0-root_mean_squared_error:6.67880
# [60]	validation_0-rmse:6.67587	validation_0-root_mean_squared_error:6.67587
# [61]	validation_0-rmse:6.66870	validation_0-root_mean_squared_error:6.66870
# [62]	validation_0-rmse:6.66150	validation_0-root_mean_squared_error:6.66150
# [63]	validation_0-rmse:6.65852	validation_0-root_mean_squared_error:6.65852
# [64]	validation_0-rmse:6.65024	validation_0-root_mean_squared_error:6.65024
# [65]	validation_0-rmse:6.64215	validation_0-root_mean_squared_error:6.64215
# [66]	validation_0-rmse:6.61668	validation_0-root_mean_squared_error:6.61668
# [67]	validation_0-rmse:6.60948	validation_0-root_mean_squared_error:6.60948
# [68]	validation_0-rmse:6.60658	validation_0-root_mean_squared_error:6.60658
# [69]	validation_0-rmse:6.60300	validation_0-root_mean_squared_error:6.60300
# [70]	validation_0-rmse:6.59951	validation_0-root_mean_squared_error:6.59951
# [71]	validation_0-rmse:6.59620	validation_0-root_mean_squared_error:6.59620
# [72]	validation_0-rmse:6.58659	validation_0-root_mean_squared_error:6.58659
# [73]	validation_0-rmse:6.58454	validation_0-root_mean_squared_error:6.58454
# [74]	validation_0-rmse:6.58253	validation_0-root_mean_squared_error:6.58252
# [75]	validation_0-rmse:6.57423	validation_0-root_mean_squared_error:6.57423
# [76]	validation_0-rmse:6.57021	validation_0-root_mean_squared_error:6.57021
# [77]	validation_0-rmse:6.56337	validation_0-root_mean_squared_error:6.56337
# [78]	validation_0-rmse:6.56014	validation_0-root_mean_squared_error:6.56014
# [79]	validation_0-rmse:6.55844	validation_0-root_mean_squared_error:6.55844
# [80]	validation_0-rmse:6.54268	validation_0-root_mean_squared_error:6.54268
# [81]	validation_0-rmse:6.53604	validation_0-root_mean_squared_error:6.53604
# [82]	validation_0-rmse:6.53445	validation_0-root_mean_squared_error:6.53445
# [83]	validation_0-rmse:6.53076	validation_0-root_mean_squared_error:6.53076
# [84]	validation_0-rmse:6.52690	validation_0-root_mean_squared_error:6.52690
# [85]	validation_0-rmse:6.51406	validation_0-root_mean_squared_error:6.51407
# [86]	validation_0-rmse:6.48852	validation_0-root_mean_squared_error:6.48852
# [87]	validation_0-rmse:6.48012	validation_0-root_mean_squared_error:6.48012
# [88]	validation_0-rmse:6.47487	validation_0-root_mean_squared_error:6.47487
# [89]	validation_0-rmse:6.47264	validation_0-root_mean_squared_error:6.47264
# [90]	validation_0-rmse:6.47068	validation_0-root_mean_squared_error:6.47067
# [91]	validation_0-rmse:6.46955	validation_0-root_mean_squared_error:6.46955
# [92]	validation_0-rmse:6.46594	validation_0-root_mean_squared_error:6.46594
# [93]	validation_0-rmse:6.46286	validation_0-root_mean_squared_error:6.46286
# [94]	validation_0-rmse:6.46203	validation_0-root_mean_squared_error:6.46204
# [95]	validation_0-rmse:6.45749	validation_0-root_mean_squared_error:6.45749
# [96]	validation_0-rmse:6.45497	validation_0-root_mean_squared_error:6.45497
# [97]	validation_0-rmse:6.45344	validation_0-root_mean_squared_error:6.45345
# [98]	validation_0-rmse:6.45230	validation_0-root_mean_squared_error:6.45230
# [99]	validation_0-rmse:6.44258	validation_0-root_mean_squared_error:6.44258
# [100]	validation_0-rmse:6.42964	validation_0-root_mean_squared_error:6.42964
# [101]	validation_0-rmse:6.42779	validation_0-root_mean_squared_error:6.42779
# [102]	validation_0-rmse:6.42498	validation_0-root_mean_squared_error:6.42499
# [103]	validation_0-rmse:6.38961	validation_0-root_mean_squared_error:6.38961
# [104]	validation_0-rmse:6.38709	validation_0-root_mean_squared_error:6.38709
# [105]	validation_0-rmse:6.38406	validation_0-root_mean_squared_error:6.38406
# [106]	validation_0-rmse:6.37672	validation_0-root_mean_squared_error:6.37672
# [107]	validation_0-rmse:6.37165	validation_0-root_mean_squared_error:6.37165
# [108]	validation_0-rmse:6.36782	validation_0-root_mean_squared_error:6.36782
# [109]	validation_0-rmse:6.36679	validation_0-root_mean_squared_error:6.36679
# [110]	validation_0-rmse:6.35769	validation_0-root_mean_squared_error:6.35769
# [111]	validation_0-rmse:6.35187	validation_0-root_mean_squared_error:6.35187
# [112]	validation_0-rmse:6.34161	validation_0-root_mean_squared_error:6.34161
# [113]	validation_0-rmse:6.33665	validation_0-root_mean_squared_error:6.33665
# [114]	validation_0-rmse:6.31249	validation_0-root_mean_squared_error:6.31249
# [115]	validation_0-rmse:6.31118	validation_0-root_mean_squared_error:6.31118
# [116]	validation_0-rmse:6.29700	validation_0-root_mean_squared_error:6.29700
# [117]	validation_0-rmse:6.29409	validation_0-root_mean_squared_error:6.29409
# [118]	validation_0-rmse:6.28284	validation_0-root_mean_squared_error:6.28284
# [119]	validation_0-rmse:6.28093	validation_0-root_mean_squared_error:6.28092
# [120]	validation_0-rmse:6.27810	validation_0-root_mean_squared_error:6.27810
# [121]	validation_0-rmse:6.27667	validation_0-root_mean_squared_error:6.27667
# [122]	validation_0-rmse:6.27073	validation_0-root_mean_squared_error:6.27073
# [123]	validation_0-rmse:6.26870	validation_0-root_mean_squared_error:6.26870
# [124]	validation_0-rmse:6.26692	validation_0-root_mean_squared_error:6.26692
# [125]	validation_0-rmse:6.25650	validation_0-root_mean_squared_error:6.25650
# [126]	validation_0-rmse:6.25296	validation_0-root_mean_squared_error:6.25295
# [127]	validation_0-rmse:6.25163	validation_0-root_mean_squared_error:6.25163
# [128]	validation_0-rmse:6.25049	validation_0-root_mean_squared_error:6.25049
# [129]	validation_0-rmse:6.24232	validation_0-root_mean_squared_error:6.24232
# [130]	validation_0-rmse:6.23916	validation_0-root_mean_squared_error:6.23916
# [131]	validation_0-rmse:6.23273	validation_0-root_mean_squared_error:6.23273
# [132]	validation_0-rmse:6.22410	validation_0-root_mean_squared_error:6.22410
# [133]	validation_0-rmse:6.22286	validation_0-root_mean_squared_error:6.22286
# [134]	validation_0-rmse:6.22193	validation_0-root_mean_squared_error:6.22193
# [135]	validation_0-rmse:6.22041	validation_0-root_mean_squared_error:6.22042
# [136]	validation_0-rmse:6.21102	validation_0-root_mean_squared_error:6.21101
# [137]	validation_0-rmse:6.20254	validation_0-root_mean_squared_error:6.20254
# [138]	validation_0-rmse:6.20076	validation_0-root_mean_squared_error:6.20076
# [139]	validation_0-rmse:6.19928	validation_0-root_mean_squared_error:6.19928
# [140]	validation_0-rmse:6.19769	validation_0-root_mean_squared_error:6.19769
# [141]	validation_0-rmse:6.18517	validation_0-root_mean_squared_error:6.18517
# [142]	validation_0-rmse:6.18404	validation_0-root_mean_squared_error:6.18403
# [143]	validation_0-rmse:6.17980	validation_0-root_mean_squared_error:6.17980
# [144]	validation_0-rmse:6.16300	validation_0-root_mean_squared_error:6.16300
# [145]	validation_0-rmse:6.16023	validation_0-root_mean_squared_error:6.16022
# [146]	validation_0-rmse:6.15906	validation_0-root_mean_squared_error:6.15906
# [147]	validation_0-rmse:6.15810	validation_0-root_mean_squared_error:6.15810
# [148]	validation_0-rmse:6.15727	validation_0-root_mean_squared_error:6.15727
# [149]	validation_0-rmse:6.15573	validation_0-root_mean_squared_error:6.15573
# [150]	validation_0-rmse:6.15492	validation_0-root_mean_squared_error:6.15492
# [151]	validation_0-rmse:6.14483	validation_0-root_mean_squared_error:6.14483
# [152]	validation_0-rmse:6.13811	validation_0-root_mean_squared_error:6.13811
# [153]	validation_0-rmse:6.13647	validation_0-root_mean_squared_error:6.13647
# [154]	validation_0-rmse:6.13507	validation_0-root_mean_squared_error:6.13507
# [155]	validation_0-rmse:6.12899	validation_0-root_mean_squared_error:6.12899
# [156]	validation_0-rmse:6.12712	validation_0-root_mean_squared_error:6.12712
# [157]	validation_0-rmse:6.12633	validation_0-root_mean_squared_error:6.12633
# [158]	validation_0-rmse:6.12432	validation_0-root_mean_squared_error:6.12432
# [159]	validation_0-rmse:6.11623	validation_0-root_mean_squared_error:6.11623
# [160]	validation_0-rmse:6.11540	validation_0-root_mean_squared_error:6.11540
# [161]	validation_0-rmse:6.11405	validation_0-root_mean_squared_error:6.11406
# [162]	validation_0-rmse:6.11172	validation_0-root_mean_squared_error:6.11172
# [163]	validation_0-rmse:6.11035	validation_0-root_mean_squared_error:6.11035
# [164]	validation_0-rmse:6.10949	validation_0-root_mean_squared_error:6.10949
# [165]	validation_0-rmse:6.10908	validation_0-root_mean_squared_error:6.10908
# [166]	validation_0-rmse:6.10713	validation_0-root_mean_squared_error:6.10713
# [167]	validation_0-rmse:6.10532	validation_0-root_mean_squared_error:6.10532
# [168]	validation_0-rmse:6.10412	validation_0-root_mean_squared_error:6.10412
# [169]	validation_0-rmse:6.10320	validation_0-root_mean_squared_error:6.10320
# [170]	validation_0-rmse:6.09894	validation_0-root_mean_squared_error:6.09894
# [171]	validation_0-rmse:6.09690	validation_0-root_mean_squared_error:6.09690
# [172]	validation_0-rmse:6.08013	validation_0-root_mean_squared_error:6.08013
# [173]	validation_0-rmse:6.07696	validation_0-root_mean_squared_error:6.07697
# [174]	validation_0-rmse:6.07541	validation_0-root_mean_squared_error:6.07541
# [175]	validation_0-rmse:6.06957	validation_0-root_mean_squared_error:6.06957
# [176]	validation_0-rmse:6.06771	validation_0-root_mean_squared_error:6.06771
# [177]	validation_0-rmse:6.06608	validation_0-root_mean_squared_error:6.06608
# [178]	validation_0-rmse:6.06510	validation_0-root_mean_squared_error:6.06510
# [179]	validation_0-rmse:6.06154	validation_0-root_mean_squared_error:6.06154
# [180]	validation_0-rmse:6.06009	validation_0-root_mean_squared_error:6.06008
# [181]	validation_0-rmse:6.04828	validation_0-root_mean_squared_error:6.04828
# [182]	validation_0-rmse:6.03764	validation_0-root_mean_squared_error:6.03765
# [183]	validation_0-rmse:6.02309	validation_0-root_mean_squared_error:6.02309
# [184]	validation_0-rmse:6.00974	validation_0-root_mean_squared_error:6.00974
# [185]	validation_0-rmse:6.00208	validation_0-root_mean_squared_error:6.00208
# [186]	validation_0-rmse:5.99383	validation_0-root_mean_squared_error:5.99383
# [187]	validation_0-rmse:5.97978	validation_0-root_mean_squared_error:5.97978
# [188]	validation_0-rmse:5.96543	validation_0-root_mean_squared_error:5.96543
# [189]	validation_0-rmse:5.96347	validation_0-root_mean_squared_error:5.96347
# [190]	validation_0-rmse:5.96148	validation_0-root_mean_squared_error:5.96148
# [191]	validation_0-rmse:5.95855	validation_0-root_mean_squared_error:5.95855
# [192]	validation_0-rmse:5.95189	validation_0-root_mean_squared_error:5.95189
# [193]	validation_0-rmse:5.94697	validation_0-root_mean_squared_error:5.94697
# [194]	validation_0-rmse:5.94552	validation_0-root_mean_squared_error:5.94552
# [195]	validation_0-rmse:5.94488	validation_0-root_mean_squared_error:5.94488
# [196]	validation_0-rmse:5.94410	validation_0-root_mean_squared_error:5.94410
# [197]	validation_0-rmse:5.93691	validation_0-root_mean_squared_error:5.93691
# [198]	validation_0-rmse:5.93572	validation_0-root_mean_squared_error:5.93572
# [199]	validation_0-rmse:5.93289	validation_0-root_mean_squared_error:5.93289
# [200]	validation_0-rmse:5.92941	validation_0-root_mean_squared_error:5.92941
# [201]	validation_0-rmse:5.92898	validation_0-root_mean_squared_error:5.92898
# [202]	validation_0-rmse:5.92545	validation_0-root_mean_squared_error:5.92544
# [203]	validation_0-rmse:5.92448	validation_0-root_mean_squared_error:5.92448
# [204]	validation_0-rmse:5.92353	validation_0-root_mean_squared_error:5.92353
# [205]	validation_0-rmse:5.92252	validation_0-root_mean_squared_error:5.92252
# [206]	validation_0-rmse:5.92088	validation_0-root_mean_squared_error:5.92088
# [207]	validation_0-rmse:5.92007	validation_0-root_mean_squared_error:5.92007
# [208]	validation_0-rmse:5.91965	validation_0-root_mean_squared_error:5.91965
# [209]	validation_0-rmse:5.91788	validation_0-root_mean_squared_error:5.91789
# [210]	validation_0-rmse:5.91747	validation_0-root_mean_squared_error:5.91747
# [211]	validation_0-rmse:5.91559	validation_0-root_mean_squared_error:5.91559
# [212]	validation_0-rmse:5.91396	validation_0-root_mean_squared_error:5.91396
# [213]	validation_0-rmse:5.91317	validation_0-root_mean_squared_error:5.91317
# [214]	validation_0-rmse:5.90915	validation_0-root_mean_squared_error:5.90915
# [215]	validation_0-rmse:5.90790	validation_0-root_mean_squared_error:5.90790
# [216]	validation_0-rmse:5.90721	validation_0-root_mean_squared_error:5.90721
# [217]	validation_0-rmse:5.90554	validation_0-root_mean_squared_error:5.90554
# [218]	validation_0-rmse:5.90255	validation_0-root_mean_squared_error:5.90254
# [219]	validation_0-rmse:5.90173	validation_0-root_mean_squared_error:5.90173
# [220]	validation_0-rmse:5.89698	validation_0-root_mean_squared_error:5.89698
# [221]	validation_0-rmse:5.89258	validation_0-root_mean_squared_error:5.89258
# [222]	validation_0-rmse:5.89218	validation_0-root_mean_squared_error:5.89218
# [223]	validation_0-rmse:5.88989	validation_0-root_mean_squared_error:5.88989
# [224]	validation_0-rmse:5.88935	validation_0-root_mean_squared_error:5.88935
# [225]	validation_0-rmse:5.88835	validation_0-root_mean_squared_error:5.88835
# [226]	validation_0-rmse:5.88627	validation_0-root_mean_squared_error:5.88627
# [227]	validation_0-rmse:5.87998	validation_0-root_mean_squared_error:5.87998
# [228]	validation_0-rmse:5.87501	validation_0-root_mean_squared_error:5.87501
# [229]	validation_0-rmse:5.87238	validation_0-root_mean_squared_error:5.87237
# [230]	validation_0-rmse:5.86916	validation_0-root_mean_squared_error:5.86916
# [231]	validation_0-rmse:5.86902	validation_0-root_mean_squared_error:5.86902
# [232]	validation_0-rmse:5.86636	validation_0-root_mean_squared_error:5.86636
# [233]	validation_0-rmse:5.85694	validation_0-root_mean_squared_error:5.85694
# [234]	validation_0-rmse:5.85660	validation_0-root_mean_squared_error:5.85660
# [235]	validation_0-rmse:5.84709	validation_0-root_mean_squared_error:5.84709
# train finish
# predict finish
# train start
# [0]	validation_0-rmse:8.54623	validation_0-root_mean_squared_error:8.54623
# [1]	validation_0-rmse:8.07236	validation_0-root_mean_squared_error:8.07236
# [2]	validation_0-rmse:7.82175	validation_0-root_mean_squared_error:7.82175
# [3]	validation_0-rmse:7.67246	validation_0-root_mean_squared_error:7.67246
# [4]	validation_0-rmse:7.59952	validation_0-root_mean_squared_error:7.59952
# [5]	validation_0-rmse:7.51201	validation_0-root_mean_squared_error:7.51201
# [6]	validation_0-rmse:7.46268	validation_0-root_mean_squared_error:7.46268
# [7]	validation_0-rmse:7.35787	validation_0-root_mean_squared_error:7.35787
# [8]	validation_0-rmse:7.31709	validation_0-root_mean_squared_error:7.31709
# [9]	validation_0-rmse:7.27206	validation_0-root_mean_squared_error:7.27206
# [10]	validation_0-rmse:7.24007	validation_0-root_mean_squared_error:7.24007
# [11]	validation_0-rmse:7.18350	validation_0-root_mean_squared_error:7.18350
# [12]	validation_0-rmse:7.15644	validation_0-root_mean_squared_error:7.15644
# [13]	validation_0-rmse:7.13014	validation_0-root_mean_squared_error:7.13014
# [14]	validation_0-rmse:7.11205	validation_0-root_mean_squared_error:7.11205
# [15]	validation_0-rmse:7.05316	validation_0-root_mean_squared_error:7.05316
# [16]	validation_0-rmse:7.03563	validation_0-root_mean_squared_error:7.03563
# [17]	validation_0-rmse:7.02269	validation_0-root_mean_squared_error:7.02269
# [18]	validation_0-rmse:7.00144	validation_0-root_mean_squared_error:7.00145
# [19]	validation_0-rmse:6.99040	validation_0-root_mean_squared_error:6.99040
# [20]	validation_0-rmse:6.94598	validation_0-root_mean_squared_error:6.94598
# [21]	validation_0-rmse:6.92435	validation_0-root_mean_squared_error:6.92435
# [22]	validation_0-rmse:6.91336	validation_0-root_mean_squared_error:6.91336
# [23]	validation_0-rmse:6.87724	validation_0-root_mean_squared_error:6.87724
# [24]	validation_0-rmse:6.86661	validation_0-root_mean_squared_error:6.86661
# [25]	validation_0-rmse:6.84929	validation_0-root_mean_squared_error:6.84929
# [26]	validation_0-rmse:6.83536	validation_0-root_mean_squared_error:6.83537
# [27]	validation_0-rmse:6.79884	validation_0-root_mean_squared_error:6.79884
# [28]	validation_0-rmse:6.77650	validation_0-root_mean_squared_error:6.77650
# [29]	validation_0-rmse:6.76781	validation_0-root_mean_squared_error:6.76781
# [30]	validation_0-rmse:6.75875	validation_0-root_mean_squared_error:6.75875
# [31]	validation_0-rmse:6.74248	validation_0-root_mean_squared_error:6.74248
# [32]	validation_0-rmse:6.73527	validation_0-root_mean_squared_error:6.73527
# [33]	validation_0-rmse:6.72008	validation_0-root_mean_squared_error:6.72008
# [34]	validation_0-rmse:6.71280	validation_0-root_mean_squared_error:6.71280
# [35]	validation_0-rmse:6.69627	validation_0-root_mean_squared_error:6.69627
# [36]	validation_0-rmse:6.68353	validation_0-root_mean_squared_error:6.68353
# [37]	validation_0-rmse:6.65381	validation_0-root_mean_squared_error:6.65381
# [38]	validation_0-rmse:6.64289	validation_0-root_mean_squared_error:6.64289
# [39]	validation_0-rmse:6.63894	validation_0-root_mean_squared_error:6.63894
# [40]	validation_0-rmse:6.63179	validation_0-root_mean_squared_error:6.63179
# [41]	validation_0-rmse:6.62263	validation_0-root_mean_squared_error:6.62263
# [42]	validation_0-rmse:6.61878	validation_0-root_mean_squared_error:6.61878
# [43]	validation_0-rmse:6.61546	validation_0-root_mean_squared_error:6.61546
# [44]	validation_0-rmse:6.60578	validation_0-root_mean_squared_error:6.60578
# [45]	validation_0-rmse:6.57754	validation_0-root_mean_squared_error:6.57754
# [46]	validation_0-rmse:6.55334	validation_0-root_mean_squared_error:6.55334
# [47]	validation_0-rmse:6.54046	validation_0-root_mean_squared_error:6.54046
# [48]	validation_0-rmse:6.53545	validation_0-root_mean_squared_error:6.53545
# [49]	validation_0-rmse:6.52238	validation_0-root_mean_squared_error:6.52238
# [50]	validation_0-rmse:6.51556	validation_0-root_mean_squared_error:6.51555
# [51]	validation_0-rmse:6.50704	validation_0-root_mean_squared_error:6.50704
# [52]	validation_0-rmse:6.50123	validation_0-root_mean_squared_error:6.50123
# [53]	validation_0-rmse:6.49529	validation_0-root_mean_squared_error:6.49529
# [54]	validation_0-rmse:6.48729	validation_0-root_mean_squared_error:6.48728
# [55]	validation_0-rmse:6.48161	validation_0-root_mean_squared_error:6.48161
# [56]	validation_0-rmse:6.47791	validation_0-root_mean_squared_error:6.47791
# [57]	validation_0-rmse:6.46807	validation_0-root_mean_squared_error:6.46807
# [58]	validation_0-rmse:6.46104	validation_0-root_mean_squared_error:6.46104
# [59]	validation_0-rmse:6.44408	validation_0-root_mean_squared_error:6.44408
# [60]	validation_0-rmse:6.43979	validation_0-root_mean_squared_error:6.43979
# [61]	validation_0-rmse:6.42017	validation_0-root_mean_squared_error:6.42018
# [62]	validation_0-rmse:6.40980	validation_0-root_mean_squared_error:6.40980
# [63]	validation_0-rmse:6.40733	validation_0-root_mean_squared_error:6.40733
# [64]	validation_0-rmse:6.40307	validation_0-root_mean_squared_error:6.40307
# [65]	validation_0-rmse:6.39916	validation_0-root_mean_squared_error:6.39916
# [66]	validation_0-rmse:6.39472	validation_0-root_mean_squared_error:6.39471
# [67]	validation_0-rmse:6.39267	validation_0-root_mean_squared_error:6.39267
# [68]	validation_0-rmse:6.38952	validation_0-root_mean_squared_error:6.38952
# [69]	validation_0-rmse:6.38757	validation_0-root_mean_squared_error:6.38757
# [70]	validation_0-rmse:6.38425	validation_0-root_mean_squared_error:6.38425
# [71]	validation_0-rmse:6.35763	validation_0-root_mean_squared_error:6.35763
# [72]	validation_0-rmse:6.32791	validation_0-root_mean_squared_error:6.32791
# [73]	validation_0-rmse:6.29791	validation_0-root_mean_squared_error:6.29791
# [74]	validation_0-rmse:6.29402	validation_0-root_mean_squared_error:6.29403
# [75]	validation_0-rmse:6.25916	validation_0-root_mean_squared_error:6.25916
# [76]	validation_0-rmse:6.25383	validation_0-root_mean_squared_error:6.25383
# [77]	validation_0-rmse:6.24146	validation_0-root_mean_squared_error:6.24146
# [78]	validation_0-rmse:6.23787	validation_0-root_mean_squared_error:6.23787
# [79]	validation_0-rmse:6.23166	validation_0-root_mean_squared_error:6.23166
# [80]	validation_0-rmse:6.21189	validation_0-root_mean_squared_error:6.21189
# [81]	validation_0-rmse:6.20075	validation_0-root_mean_squared_error:6.20075
# [82]	validation_0-rmse:6.19593	validation_0-root_mean_squared_error:6.19594
# [83]	validation_0-rmse:6.19205	validation_0-root_mean_squared_error:6.19205
# [84]	validation_0-rmse:6.19076	validation_0-root_mean_squared_error:6.19076
# [85]	validation_0-rmse:6.16090	validation_0-root_mean_squared_error:6.16090
# [86]	validation_0-rmse:6.14606	validation_0-root_mean_squared_error:6.14606
# [87]	validation_0-rmse:6.13491	validation_0-root_mean_squared_error:6.13491
# [88]	validation_0-rmse:6.13008	validation_0-root_mean_squared_error:6.13008
# [89]	validation_0-rmse:6.12708	validation_0-root_mean_squared_error:6.12708
# [90]	validation_0-rmse:6.12257	validation_0-root_mean_squared_error:6.12257
# [91]	validation_0-rmse:6.12103	validation_0-root_mean_squared_error:6.12103
# [92]	validation_0-rmse:6.11842	validation_0-root_mean_squared_error:6.11841
# [93]	validation_0-rmse:6.11281	validation_0-root_mean_squared_error:6.11281
# [94]	validation_0-rmse:6.10528	validation_0-root_mean_squared_error:6.10528
# [95]	validation_0-rmse:6.09451	validation_0-root_mean_squared_error:6.09451
# [96]	validation_0-rmse:6.09204	validation_0-root_mean_squared_error:6.09204
# [97]	validation_0-rmse:6.08515	validation_0-root_mean_squared_error:6.08515
# [98]	validation_0-rmse:6.08288	validation_0-root_mean_squared_error:6.08288
# [99]	validation_0-rmse:6.08178	validation_0-root_mean_squared_error:6.08178
# [100]	validation_0-rmse:6.07519	validation_0-root_mean_squared_error:6.07519
# [101]	validation_0-rmse:6.07337	validation_0-root_mean_squared_error:6.07336
# [102]	validation_0-rmse:6.07109	validation_0-root_mean_squared_error:6.07109
# [103]	validation_0-rmse:6.06615	validation_0-root_mean_squared_error:6.06615
# [104]	validation_0-rmse:6.06354	validation_0-root_mean_squared_error:6.06354
# [105]	validation_0-rmse:6.05956	validation_0-root_mean_squared_error:6.05956
# [106]	validation_0-rmse:6.04048	validation_0-root_mean_squared_error:6.04048
# [107]	validation_0-rmse:6.03569	validation_0-root_mean_squared_error:6.03569
# [108]	validation_0-rmse:6.03005	validation_0-root_mean_squared_error:6.03006
# [109]	validation_0-rmse:6.02796	validation_0-root_mean_squared_error:6.02796
# [110]	validation_0-rmse:6.02646	validation_0-root_mean_squared_error:6.02646
# [111]	validation_0-rmse:6.02363	validation_0-root_mean_squared_error:6.02363
# [112]	validation_0-rmse:6.02074	validation_0-root_mean_squared_error:6.02074
# [113]	validation_0-rmse:6.01412	validation_0-root_mean_squared_error:6.01412
# [114]	validation_0-rmse:6.00902	validation_0-root_mean_squared_error:6.00903
# [115]	validation_0-rmse:6.00506	validation_0-root_mean_squared_error:6.00506
# [116]	validation_0-rmse:6.00309	validation_0-root_mean_squared_error:6.00309
# [117]	validation_0-rmse:5.99925	validation_0-root_mean_squared_error:5.99925
# [118]	validation_0-rmse:5.99736	validation_0-root_mean_squared_error:5.99736
# [119]	validation_0-rmse:5.99349	validation_0-root_mean_squared_error:5.99349
# [120]	validation_0-rmse:5.98945	validation_0-root_mean_squared_error:5.98946
# [121]	validation_0-rmse:5.98245	validation_0-root_mean_squared_error:5.98245
# [122]	validation_0-rmse:5.97139	validation_0-root_mean_squared_error:5.97139
# [123]	validation_0-rmse:5.96894	validation_0-root_mean_squared_error:5.96894
# [124]	validation_0-rmse:5.96728	validation_0-root_mean_squared_error:5.96728
# [125]	validation_0-rmse:5.95321	validation_0-root_mean_squared_error:5.95321
# [126]	validation_0-rmse:5.92399	validation_0-root_mean_squared_error:5.92399
# [127]	validation_0-rmse:5.92279	validation_0-root_mean_squared_error:5.92279
# [128]	validation_0-rmse:5.92066	validation_0-root_mean_squared_error:5.92066
# [129]	validation_0-rmse:5.91153	validation_0-root_mean_squared_error:5.91153
# [130]	validation_0-rmse:5.91101	validation_0-root_mean_squared_error:5.91101
# [131]	validation_0-rmse:5.90908	validation_0-root_mean_squared_error:5.90908
# [132]	validation_0-rmse:5.90757	validation_0-root_mean_squared_error:5.90756
# [133]	validation_0-rmse:5.90547	validation_0-root_mean_squared_error:5.90547
# [134]	validation_0-rmse:5.90451	validation_0-root_mean_squared_error:5.90451
# [135]	validation_0-rmse:5.90242	validation_0-root_mean_squared_error:5.90242
# [136]	validation_0-rmse:5.90073	validation_0-root_mean_squared_error:5.90073
# [137]	validation_0-rmse:5.89121	validation_0-root_mean_squared_error:5.89121
# [138]	validation_0-rmse:5.88957	validation_0-root_mean_squared_error:5.88957
# [139]	validation_0-rmse:5.88889	validation_0-root_mean_squared_error:5.88889
# [140]	validation_0-rmse:5.88544	validation_0-root_mean_squared_error:5.88544
# [141]	validation_0-rmse:5.88366	validation_0-root_mean_squared_error:5.88366
# [142]	validation_0-rmse:5.88308	validation_0-root_mean_squared_error:5.88308
# [143]	validation_0-rmse:5.88037	validation_0-root_mean_squared_error:5.88037
# [144]	validation_0-rmse:5.87401	validation_0-root_mean_squared_error:5.87401
# [145]	validation_0-rmse:5.87313	validation_0-root_mean_squared_error:5.87313
# [146]	validation_0-rmse:5.87098	validation_0-root_mean_squared_error:5.87098
# [147]	validation_0-rmse:5.85406	validation_0-root_mean_squared_error:5.85406
# [148]	validation_0-rmse:5.84371	validation_0-root_mean_squared_error:5.84371
# [149]	validation_0-rmse:5.84018	validation_0-root_mean_squared_error:5.84018
# [150]	validation_0-rmse:5.82660	validation_0-root_mean_squared_error:5.82660
# [151]	validation_0-rmse:5.82487	validation_0-root_mean_squared_error:5.82487
# [152]	validation_0-rmse:5.82280	validation_0-root_mean_squared_error:5.82280
# [153]	validation_0-rmse:5.82195	validation_0-root_mean_squared_error:5.82195
# [154]	validation_0-rmse:5.82060	validation_0-root_mean_squared_error:5.82060
# [155]	validation_0-rmse:5.81086	validation_0-root_mean_squared_error:5.81086
# [156]	validation_0-rmse:5.78903	validation_0-root_mean_squared_error:5.78903
# [157]	validation_0-rmse:5.77614	validation_0-root_mean_squared_error:5.77614
# [158]	validation_0-rmse:5.76480	validation_0-root_mean_squared_error:5.76480
# [159]	validation_0-rmse:5.75254	validation_0-root_mean_squared_error:5.75253
# [160]	validation_0-rmse:5.72835	validation_0-root_mean_squared_error:5.72835
# [161]	validation_0-rmse:5.70840	validation_0-root_mean_squared_error:5.70840
# [162]	validation_0-rmse:5.69333	validation_0-root_mean_squared_error:5.69333
# [163]	validation_0-rmse:5.68878	validation_0-root_mean_squared_error:5.68878
# [164]	validation_0-rmse:5.67833	validation_0-root_mean_squared_error:5.67833
# [165]	validation_0-rmse:5.66499	validation_0-root_mean_squared_error:5.66499
# [166]	validation_0-rmse:5.65879	validation_0-root_mean_squared_error:5.65879
# [167]	validation_0-rmse:5.65083	validation_0-root_mean_squared_error:5.65083
# [168]	validation_0-rmse:5.64109	validation_0-root_mean_squared_error:5.64109
# [169]	validation_0-rmse:5.63893	validation_0-root_mean_squared_error:5.63893
# [170]	validation_0-rmse:5.62683	validation_0-root_mean_squared_error:5.62682
# [171]	validation_0-rmse:5.62339	validation_0-root_mean_squared_error:5.62339
# [172]	validation_0-rmse:5.61785	validation_0-root_mean_squared_error:5.61785
# [173]	validation_0-rmse:5.61581	validation_0-root_mean_squared_error:5.61581
# [174]	validation_0-rmse:5.61297	validation_0-root_mean_squared_error:5.61297
# [175]	validation_0-rmse:5.60778	validation_0-root_mean_squared_error:5.60778
# [176]	validation_0-rmse:5.60688	validation_0-root_mean_squared_error:5.60687
# [177]	validation_0-rmse:5.60264	validation_0-root_mean_squared_error:5.60264
# [178]	validation_0-rmse:5.59466	validation_0-root_mean_squared_error:5.59466
# [179]	validation_0-rmse:5.59287	validation_0-root_mean_squared_error:5.59287
# [180]	validation_0-rmse:5.59239	validation_0-root_mean_squared_error:5.59239
# [181]	validation_0-rmse:5.59002	validation_0-root_mean_squared_error:5.59002
# [182]	validation_0-rmse:5.58476	validation_0-root_mean_squared_error:5.58476
# [183]	validation_0-rmse:5.58271	validation_0-root_mean_squared_error:5.58271
# [184]	validation_0-rmse:5.58136	validation_0-root_mean_squared_error:5.58136
# [185]	validation_0-rmse:5.57961	validation_0-root_mean_squared_error:5.57961
# [186]	validation_0-rmse:5.57892	validation_0-root_mean_squared_error:5.57892
# [187]	validation_0-rmse:5.57791	validation_0-root_mean_squared_error:5.57791
# [188]	validation_0-rmse:5.57597	validation_0-root_mean_squared_error:5.57596
# [189]	validation_0-rmse:5.57419	validation_0-root_mean_squared_error:5.57418
# [190]	validation_0-rmse:5.57161	validation_0-root_mean_squared_error:5.57161
# [191]	validation_0-rmse:5.57057	validation_0-root_mean_squared_error:5.57057
# [192]	validation_0-rmse:5.56957	validation_0-root_mean_squared_error:5.56957
# [193]	validation_0-rmse:5.56896	validation_0-root_mean_squared_error:5.56896
# [194]	validation_0-rmse:5.56847	validation_0-root_mean_squared_error:5.56847
# [195]	validation_0-rmse:5.56291	validation_0-root_mean_squared_error:5.56291
# [196]	validation_0-rmse:5.55533	validation_0-root_mean_squared_error:5.55533
# [197]	validation_0-rmse:5.54543	validation_0-root_mean_squared_error:5.54542
# [198]	validation_0-rmse:5.54472	validation_0-root_mean_squared_error:5.54472
# [199]	validation_0-rmse:5.54172	validation_0-root_mean_squared_error:5.54171
# [200]	validation_0-rmse:5.53876	validation_0-root_mean_squared_error:5.53876
# [201]	validation_0-rmse:5.53530	validation_0-root_mean_squared_error:5.53530
# [202]	validation_0-rmse:5.52902	validation_0-root_mean_squared_error:5.52902
# [203]	validation_0-rmse:5.52792	validation_0-root_mean_squared_error:5.52792
# [204]	validation_0-rmse:5.52698	validation_0-root_mean_squared_error:5.52698
# [205]	validation_0-rmse:5.52650	validation_0-root_mean_squared_error:5.52650
# [206]	validation_0-rmse:5.52527	validation_0-root_mean_squared_error:5.52527
# [207]	validation_0-rmse:5.52259	validation_0-root_mean_squared_error:5.52259
# [208]	validation_0-rmse:5.52228	validation_0-root_mean_squared_error:5.52228
# [209]	validation_0-rmse:5.51335	validation_0-root_mean_squared_error:5.51335
# [210]	validation_0-rmse:5.50545	validation_0-root_mean_squared_error:5.50545
# [211]	validation_0-rmse:5.50161	validation_0-root_mean_squared_error:5.50162
# [212]	validation_0-rmse:5.49552	validation_0-root_mean_squared_error:5.49552
# [213]	validation_0-rmse:5.49355	validation_0-root_mean_squared_error:5.49355
# [214]	validation_0-rmse:5.49305	validation_0-root_mean_squared_error:5.49305
# [215]	validation_0-rmse:5.49256	validation_0-root_mean_squared_error:5.49256
# [216]	validation_0-rmse:5.49122	validation_0-root_mean_squared_error:5.49122
# [217]	validation_0-rmse:5.49055	validation_0-root_mean_squared_error:5.49055
# [218]	validation_0-rmse:5.48881	validation_0-root_mean_squared_error:5.48881
# [219]	validation_0-rmse:5.48837	validation_0-root_mean_squared_error:5.48836
# [220]	validation_0-rmse:5.48794	validation_0-root_mean_squared_error:5.48794
# [221]	validation_0-rmse:5.48734	validation_0-root_mean_squared_error:5.48734
# [222]	validation_0-rmse:5.48522	validation_0-root_mean_squared_error:5.48522
# [223]	validation_0-rmse:5.47997	validation_0-root_mean_squared_error:5.47997
# [224]	validation_0-rmse:5.47935	validation_0-root_mean_squared_error:5.47935
# [225]	validation_0-rmse:5.47573	validation_0-root_mean_squared_error:5.47573
# [226]	validation_0-rmse:5.47526	validation_0-root_mean_squared_error:5.47526
# [227]	validation_0-rmse:5.47119	validation_0-root_mean_squared_error:5.47119
# [228]	validation_0-rmse:5.47001	validation_0-root_mean_squared_error:5.47001
# [229]	validation_0-rmse:5.46947	validation_0-root_mean_squared_error:5.46947
# [230]	validation_0-rmse:5.46689	validation_0-root_mean_squared_error:5.46690
# [231]	validation_0-rmse:5.46656	validation_0-root_mean_squared_error:5.46656
# [232]	validation_0-rmse:5.46619	validation_0-root_mean_squared_error:5.46619
# [233]	validation_0-rmse:5.46551	validation_0-root_mean_squared_error:5.46551
# [234]	validation_0-rmse:5.46492	validation_0-root_mean_squared_error:5.46492
# [235]	validation_0-rmse:5.46439	validation_0-root_mean_squared_error:5.46439
# [236]	validation_0-rmse:5.46405	validation_0-root_mean_squared_error:5.46405
# [237]	validation_0-rmse:5.46328	validation_0-root_mean_squared_error:5.46328
# [238]	validation_0-rmse:5.46106	validation_0-root_mean_squared_error:5.46106
# [239]	validation_0-rmse:5.45836	validation_0-root_mean_squared_error:5.45836
# [240]	validation_0-rmse:5.45643	validation_0-root_mean_squared_error:5.45643
# [241]	validation_0-rmse:5.45560	validation_0-root_mean_squared_error:5.45560
# [242]	validation_0-rmse:5.45493	validation_0-root_mean_squared_error:5.45493
# [243]	validation_0-rmse:5.45386	validation_0-root_mean_squared_error:5.45386
# [244]	validation_0-rmse:5.45330	validation_0-root_mean_squared_error:5.45330
# [245]	validation_0-rmse:5.44914	validation_0-root_mean_squared_error:5.44914
# [246]	validation_0-rmse:5.44373	validation_0-root_mean_squared_error:5.44373
# train finish
# predict finish
# train start
# [0]	validation_0-rmse:8.02772	validation_0-root_mean_squared_error:8.02772
# [1]	validation_0-rmse:7.70173	validation_0-root_mean_squared_error:7.70174
# [2]	validation_0-rmse:7.46338	validation_0-root_mean_squared_error:7.46337
# [3]	validation_0-rmse:7.34079	validation_0-root_mean_squared_error:7.34079
# [4]	validation_0-rmse:7.16832	validation_0-root_mean_squared_error:7.16832
# [5]	validation_0-rmse:7.10322	validation_0-root_mean_squared_error:7.10322
# [6]	validation_0-rmse:7.03673	validation_0-root_mean_squared_error:7.03673
# [7]	validation_0-rmse:6.93914	validation_0-root_mean_squared_error:6.93914
# [8]	validation_0-rmse:6.89616	validation_0-root_mean_squared_error:6.89616
# [9]	validation_0-rmse:6.80473	validation_0-root_mean_squared_error:6.80473
# [10]	validation_0-rmse:6.72077	validation_0-root_mean_squared_error:6.72077
# [11]	validation_0-rmse:6.70263	validation_0-root_mean_squared_error:6.70263
# [12]	validation_0-rmse:6.67393	validation_0-root_mean_squared_error:6.67393
# [13]	validation_0-rmse:6.64944	validation_0-root_mean_squared_error:6.64944
# [14]	validation_0-rmse:6.61221	validation_0-root_mean_squared_error:6.61221
# [15]	validation_0-rmse:6.57263	validation_0-root_mean_squared_error:6.57263
# [16]	validation_0-rmse:6.53663	validation_0-root_mean_squared_error:6.53663
# [17]	validation_0-rmse:6.52018	validation_0-root_mean_squared_error:6.52018
# [18]	validation_0-rmse:6.50938	validation_0-root_mean_squared_error:6.50938
# [19]	validation_0-rmse:6.49635	validation_0-root_mean_squared_error:6.49635
# [20]	validation_0-rmse:6.47425	validation_0-root_mean_squared_error:6.47425
# [21]	validation_0-rmse:6.41336	validation_0-root_mean_squared_error:6.41336
# [22]	validation_0-rmse:6.35978	validation_0-root_mean_squared_error:6.35978
# [23]	validation_0-rmse:6.31511	validation_0-root_mean_squared_error:6.31511
# [24]	validation_0-rmse:6.26801	validation_0-root_mean_squared_error:6.26801
# [25]	validation_0-rmse:6.25092	validation_0-root_mean_squared_error:6.25092
# [26]	validation_0-rmse:6.24345	validation_0-root_mean_squared_error:6.24345
# [27]	validation_0-rmse:6.22841	validation_0-root_mean_squared_error:6.22841
# [28]	validation_0-rmse:6.21582	validation_0-root_mean_squared_error:6.21582
# [29]	validation_0-rmse:6.15471	validation_0-root_mean_squared_error:6.15471
# [30]	validation_0-rmse:6.15002	validation_0-root_mean_squared_error:6.15002
# [31]	validation_0-rmse:6.13597	validation_0-root_mean_squared_error:6.13597
# [32]	validation_0-rmse:6.11081	validation_0-root_mean_squared_error:6.11081
# [33]	validation_0-rmse:6.09685	validation_0-root_mean_squared_error:6.09685
# [34]	validation_0-rmse:6.06673	validation_0-root_mean_squared_error:6.06673
# [35]	validation_0-rmse:6.04665	validation_0-root_mean_squared_error:6.04665
# [36]	validation_0-rmse:6.03388	validation_0-root_mean_squared_error:6.03388
# [37]	validation_0-rmse:6.00955	validation_0-root_mean_squared_error:6.00955
# [38]	validation_0-rmse:6.00396	validation_0-root_mean_squared_error:6.00396
# [39]	validation_0-rmse:5.99586	validation_0-root_mean_squared_error:5.99587
# [40]	validation_0-rmse:5.95482	validation_0-root_mean_squared_error:5.95482
# [41]	validation_0-rmse:5.94810	validation_0-root_mean_squared_error:5.94810
# [42]	validation_0-rmse:5.90899	validation_0-root_mean_squared_error:5.90899
# [43]	validation_0-rmse:5.86267	validation_0-root_mean_squared_error:5.86267
# [44]	validation_0-rmse:5.81600	validation_0-root_mean_squared_error:5.81600
# [45]	validation_0-rmse:5.77075	validation_0-root_mean_squared_error:5.77075
# [46]	validation_0-rmse:5.73257	validation_0-root_mean_squared_error:5.73257
# [47]	validation_0-rmse:5.70364	validation_0-root_mean_squared_error:5.70364
# [48]	validation_0-rmse:5.67100	validation_0-root_mean_squared_error:5.67100
# [49]	validation_0-rmse:5.64944	validation_0-root_mean_squared_error:5.64944
# [50]	validation_0-rmse:5.63601	validation_0-root_mean_squared_error:5.63601
# [51]	validation_0-rmse:5.62811	validation_0-root_mean_squared_error:5.62811
# [52]	validation_0-rmse:5.61950	validation_0-root_mean_squared_error:5.61950
# [53]	validation_0-rmse:5.59059	validation_0-root_mean_squared_error:5.59059
# [54]	validation_0-rmse:5.56829	validation_0-root_mean_squared_error:5.56829
# [55]	validation_0-rmse:5.55309	validation_0-root_mean_squared_error:5.55309
# [56]	validation_0-rmse:5.54325	validation_0-root_mean_squared_error:5.54325
# [57]	validation_0-rmse:5.53953	validation_0-root_mean_squared_error:5.53953
# [58]	validation_0-rmse:5.53607	validation_0-root_mean_squared_error:5.53607
# [59]	validation_0-rmse:5.53197	validation_0-root_mean_squared_error:5.53197
# [60]	validation_0-rmse:5.51529	validation_0-root_mean_squared_error:5.51529
# [61]	validation_0-rmse:5.50588	validation_0-root_mean_squared_error:5.50588
# [62]	validation_0-rmse:5.50373	validation_0-root_mean_squared_error:5.50373
# [63]	validation_0-rmse:5.49740	validation_0-root_mean_squared_error:5.49740
# [64]	validation_0-rmse:5.48947	validation_0-root_mean_squared_error:5.48947
# [65]	validation_0-rmse:5.48749	validation_0-root_mean_squared_error:5.48748
# [66]	validation_0-rmse:5.48171	validation_0-root_mean_squared_error:5.48171
# [67]	validation_0-rmse:5.46661	validation_0-root_mean_squared_error:5.46661
# [68]	validation_0-rmse:5.45512	validation_0-root_mean_squared_error:5.45512
# [69]	validation_0-rmse:5.45150	validation_0-root_mean_squared_error:5.45150
# [70]	validation_0-rmse:5.44638	validation_0-root_mean_squared_error:5.44637
# [71]	validation_0-rmse:5.43309	validation_0-root_mean_squared_error:5.43308
# [72]	validation_0-rmse:5.42941	validation_0-root_mean_squared_error:5.42941
# [73]	validation_0-rmse:5.41143	validation_0-root_mean_squared_error:5.41143
# [74]	validation_0-rmse:5.40724	validation_0-root_mean_squared_error:5.40724
# [75]	validation_0-rmse:5.39785	validation_0-root_mean_squared_error:5.39785
# [76]	validation_0-rmse:5.39393	validation_0-root_mean_squared_error:5.39393
# [77]	validation_0-rmse:5.38621	validation_0-root_mean_squared_error:5.38621
# [78]	validation_0-rmse:5.38007	validation_0-root_mean_squared_error:5.38007
# [79]	validation_0-rmse:5.37904	validation_0-root_mean_squared_error:5.37904
# [80]	validation_0-rmse:5.37230	validation_0-root_mean_squared_error:5.37230
# [81]	validation_0-rmse:5.36855	validation_0-root_mean_squared_error:5.36855
# [82]	validation_0-rmse:5.36640	validation_0-root_mean_squared_error:5.36640
# [83]	validation_0-rmse:5.36411	validation_0-root_mean_squared_error:5.36411
# [84]	validation_0-rmse:5.36304	validation_0-root_mean_squared_error:5.36304
# [85]	validation_0-rmse:5.36071	validation_0-root_mean_squared_error:5.36071
# [86]	validation_0-rmse:5.35960	validation_0-root_mean_squared_error:5.35960
# [87]	validation_0-rmse:5.35829	validation_0-root_mean_squared_error:5.35829
# [88]	validation_0-rmse:5.35599	validation_0-root_mean_squared_error:5.35599
# [89]	validation_0-rmse:5.35463	validation_0-root_mean_squared_error:5.35463
# [90]	validation_0-rmse:5.35303	validation_0-root_mean_squared_error:5.35303
# [91]	validation_0-rmse:5.35152	validation_0-root_mean_squared_error:5.35152
# [92]	validation_0-rmse:5.34965	validation_0-root_mean_squared_error:5.34965
# [93]	validation_0-rmse:5.34688	validation_0-root_mean_squared_error:5.34688
# [94]	validation_0-rmse:5.34622	validation_0-root_mean_squared_error:5.34621
# [95]	validation_0-rmse:5.34192	validation_0-root_mean_squared_error:5.34192
# [96]	validation_0-rmse:5.34068	validation_0-root_mean_squared_error:5.34068
# [97]	validation_0-rmse:5.33850	validation_0-root_mean_squared_error:5.33850
# [98]	validation_0-rmse:5.33572	validation_0-root_mean_squared_error:5.33572
# [99]	validation_0-rmse:5.33484	validation_0-root_mean_squared_error:5.33484
# [100]	validation_0-rmse:5.33416	validation_0-root_mean_squared_error:5.33416
# [101]	validation_0-rmse:5.33075	validation_0-root_mean_squared_error:5.33075
# [102]	validation_0-rmse:5.32865	validation_0-root_mean_squared_error:5.32865
# [103]	validation_0-rmse:5.32454	validation_0-root_mean_squared_error:5.32454
# [104]	validation_0-rmse:5.31810	validation_0-root_mean_squared_error:5.31810
# [105]	validation_0-rmse:5.31170	validation_0-root_mean_squared_error:5.31170
# [106]	validation_0-rmse:5.30824	validation_0-root_mean_squared_error:5.30824
# [107]	validation_0-rmse:5.30434	validation_0-root_mean_squared_error:5.30434
# [108]	validation_0-rmse:5.30348	validation_0-root_mean_squared_error:5.30348
# [109]	validation_0-rmse:5.30113	validation_0-root_mean_squared_error:5.30113
# [110]	validation_0-rmse:5.30018	validation_0-root_mean_squared_error:5.30018
# [111]	validation_0-rmse:5.29957	validation_0-root_mean_squared_error:5.29957
# [112]	validation_0-rmse:5.29848	validation_0-root_mean_squared_error:5.29848
# [113]	validation_0-rmse:5.29685	validation_0-root_mean_squared_error:5.29685
# [114]	validation_0-rmse:5.29622	validation_0-root_mean_squared_error:5.29622
# [115]	validation_0-rmse:5.29474	validation_0-root_mean_squared_error:5.29474
# ...
# [67]	validation_0-rmse:5.53107	validation_0-root_mean_squared_error:5.53107
# [68]	validation_0-rmse:5.49922	validation_0-root_mean_squared_error:5.49922
# [69]	validation_0-rmse:5.48397	validation_0-root_mean_squared_error:5.48397
# [70]	validation_0-rmse:5.46742	validation_0-root_mean_squared_error:5.46742
# [71]	validation_0-rmse:5.44802	validation_0-root_mean_squared_error:5.44803
# [72]	validation_0-rmse:5.43885	validation_0-root_mean_squared_error:5.43885
# [73]	validation_0-rmse:5.43722	validation_0-root_mean_squared_error:5.43722
# [74]	validation_0-rmse:5.43320	validation_0-root_mean_squared_error:5.43320
# [75]	validation_0-rmse:5.43137	validation_0-root_mean_squared_error:5.43137
# [76]	validation_0-rmse:5.41893	validation_0-root_mean_squared_error:5.41893
# [77]	validation_0-rmse:5.41290	validation_0-root_mean_squared_error:5.41290
# [78]	validation_0-rmse:5.40846	validation_0-root_mean_squared_error:5.40846
# [79]	validation_0-rmse:5.40200	validation_0-root_mean_squared_error:5.40200
# [80]	validation_0-rmse:5.39889	validation_0-root_mean_squared_error:5.39889
# [81]	validation_0-rmse:5.39477	validation_0-root_mean_squared_error:5.39477
# [82]	validation_0-rmse:5.39264	validation_0-root_mean_squared_error:5.39264
# [83]	validation_0-rmse:5.38779	validation_0-root_mean_squared_error:5.38779
# [84]	validation_0-rmse:5.37460	validation_0-root_mean_squared_error:5.37460
# [85]	validation_0-rmse:5.36721	validation_0-root_mean_squared_error:5.36721
# [86]	validation_0-rmse:5.36597	validation_0-root_mean_squared_error:5.36597
# [87]	validation_0-rmse:5.36380	validation_0-root_mean_squared_error:5.36379
# [88]	validation_0-rmse:5.36098	validation_0-root_mean_squared_error:5.36099
# [89]	validation_0-rmse:5.35817	validation_0-root_mean_squared_error:5.35817
# [90]	validation_0-rmse:5.35189	validation_0-root_mean_squared_error:5.35189
# [91]	validation_0-rmse:5.34888	validation_0-root_mean_squared_error:5.34889
# [92]	validation_0-rmse:5.34664	validation_0-root_mean_squared_error:5.34664
# [93]	validation_0-rmse:5.34519	validation_0-root_mean_squared_error:5.34519
# [94]	validation_0-rmse:5.34367	validation_0-root_mean_squared_error:5.34367
# [95]	validation_0-rmse:5.34307	validation_0-root_mean_squared_error:5.34307
# [96]	validation_0-rmse:5.34170	validation_0-root_mean_squared_error:5.34170
# [97]	validation_0-rmse:5.33982	validation_0-root_mean_squared_error:5.33982
# [98]	validation_0-rmse:5.33890	validation_0-root_mean_squared_error:5.33890
# [99]	validation_0-rmse:5.33744	validation_0-root_mean_squared_error:5.33744
# [100]	validation_0-rmse:5.33516	validation_0-root_mean_squared_error:5.33516
# [101]	validation_0-rmse:5.32982	validation_0-root_mean_squared_error:5.32982
# [102]	validation_0-rmse:5.32050	validation_0-root_mean_squared_error:5.32050
# [103]	validation_0-rmse:5.31764	validation_0-root_mean_squared_error:5.31764
# [104]	validation_0-rmse:5.31392	validation_0-root_mean_squared_error:5.31392
# [105]	validation_0-rmse:5.30601	validation_0-root_mean_squared_error:5.30601
# [106]	validation_0-rmse:5.30247	validation_0-root_mean_squared_error:5.30247
# [107]	validation_0-rmse:5.29778	validation_0-root_mean_squared_error:5.29778
# [108]	validation_0-rmse:5.29150	validation_0-root_mean_squared_error:5.29150
# [109]	validation_0-rmse:5.28968	validation_0-root_mean_squared_error:5.28968
# [110]	validation_0-rmse:5.28864	validation_0-root_mean_squared_error:5.28864
# [111]	validation_0-rmse:5.28753	validation_0-root_mean_squared_error:5.28753
# [112]	validation_0-rmse:5.28278	validation_0-root_mean_squared_error:5.28278
# [113]	validation_0-rmse:5.27946	validation_0-root_mean_squared_error:5.27946
# [114]	validation_0-rmse:5.27578	validation_0-root_mean_squared_error:5.27578
# [115]	validation_0-rmse:5.27404	validation_0-root_mean_squared_error:5.27404
# [116]	validation_0-rmse:5.27250	validation_0-root_mean_squared_error:5.27251
# [117]	validation_0-rmse:5.26959	validation_0-root_mean_squared_error:5.26959
# [118]	validation_0-rmse:5.26837	validation_0-root_mean_squared_error:5.26837
# [119]	validation_0-rmse:5.26758	validation_0-root_mean_squared_error:5.26758
# [120]	validation_0-rmse:5.26680	validation_0-root_mean_squared_error:5.26680
# [121]	validation_0-rmse:5.26284	validation_0-root_mean_squared_error:5.26284
# [122]	validation_0-rmse:5.26098	validation_0-root_mean_squared_error:5.26098
# [123]	validation_0-rmse:5.25864	validation_0-root_mean_squared_error:5.25864
# [124]	validation_0-rmse:5.25575	validation_0-root_mean_squared_error:5.25575
# [125]	validation_0-rmse:5.25479	validation_0-root_mean_squared_error:5.25479
# [126]	validation_0-rmse:5.25168	validation_0-root_mean_squared_error:5.25168
# [127]	validation_0-rmse:5.25034	validation_0-root_mean_squared_error:5.25033
# [128]	validation_0-rmse:5.24927	validation_0-root_mean_squared_error:5.24927
# [129]	validation_0-rmse:5.24770	validation_0-root_mean_squared_error:5.24770
# [130]	validation_0-rmse:5.24493	validation_0-root_mean_squared_error:5.24493
# [131]	validation_0-rmse:5.24440	validation_0-root_mean_squared_error:5.24441
# [132]	validation_0-rmse:5.24037	validation_0-root_mean_squared_error:5.24037
# [133]	validation_0-rmse:5.23711	validation_0-root_mean_squared_error:5.23711
# [134]	validation_0-rmse:5.23509	validation_0-root_mean_squared_error:5.23510
# [135]	validation_0-rmse:5.23250	validation_0-root_mean_squared_error:5.23250
# [136]	validation_0-rmse:5.22850	validation_0-root_mean_squared_error:5.22850
# [137]	validation_0-rmse:5.22664	validation_0-root_mean_squared_error:5.22664
# [138]	validation_0-rmse:5.22551	validation_0-root_mean_squared_error:5.22551
# [139]	validation_0-rmse:5.22431	validation_0-root_mean_squared_error:5.22431
# [140]	validation_0-rmse:5.22346	validation_0-root_mean_squared_error:5.22346
# [141]	validation_0-rmse:5.22238	validation_0-root_mean_squared_error:5.22237
# [142]	validation_0-rmse:5.22159	validation_0-root_mean_squared_error:5.22159
# [143]	validation_0-rmse:5.22104	validation_0-root_mean_squared_error:5.22104
# [144]	validation_0-rmse:5.22039	validation_0-root_mean_squared_error:5.22039
# [145]	validation_0-rmse:5.21964	validation_0-root_mean_squared_error:5.21964
# [146]	validation_0-rmse:5.21881	validation_0-root_mean_squared_error:5.21881
# [147]	validation_0-rmse:5.21805	validation_0-root_mean_squared_error:5.21805
# [148]	validation_0-rmse:5.21758	validation_0-root_mean_squared_error:5.21758
# [149]	validation_0-rmse:5.21639	validation_0-root_mean_squared_error:5.21639
# [150]	validation_0-rmse:5.21590	validation_0-root_mean_squared_error:5.21589
# [151]	validation_0-rmse:5.21530	validation_0-root_mean_squared_error:5.21530
# [152]	validation_0-rmse:5.21436	validation_0-root_mean_squared_error:5.21436
# [153]	validation_0-rmse:5.21358	validation_0-root_mean_squared_error:5.21359
# [154]	validation_0-rmse:5.21282	validation_0-root_mean_squared_error:5.21281
# [155]	validation_0-rmse:5.21154	validation_0-root_mean_squared_error:5.21154
# [156]	validation_0-rmse:5.21015	validation_0-root_mean_squared_error:5.21015
# [157]	validation_0-rmse:5.20941	validation_0-root_mean_squared_error:5.20941
# [158]	validation_0-rmse:5.20845	validation_0-root_mean_squared_error:5.20845
# [159]	validation_0-rmse:5.20729	validation_0-root_mean_squared_error:5.20729
# [160]	validation_0-rmse:5.20641	validation_0-root_mean_squared_error:5.20640
# [161]	validation_0-rmse:5.20585	validation_0-root_mean_squared_error:5.20585
# [162]	validation_0-rmse:5.20500	validation_0-root_mean_squared_error:5.20500
# [163]	validation_0-rmse:5.20461	validation_0-root_mean_squared_error:5.20461
# [164]	validation_0-rmse:5.20336	validation_0-root_mean_squared_error:5.20336
# [165]	validation_0-rmse:5.20123	validation_0-root_mean_squared_error:5.20123
# [166]	validation_0-rmse:5.19853	validation_0-root_mean_squared_error:5.19853
# [167]	validation_0-rmse:5.19735	validation_0-root_mean_squared_error:5.19735
# [168]	validation_0-rmse:5.19688	validation_0-root_mean_squared_error:5.19688
# [169]	validation_0-rmse:5.19618	validation_0-root_mean_squared_error:5.19618
# [170]	validation_0-rmse:5.19539	validation_0-root_mean_squared_error:5.19539
# [171]	validation_0-rmse:5.19449	validation_0-root_mean_squared_error:5.19449
# [172]	validation_0-rmse:5.19399	validation_0-root_mean_squared_error:5.19399
# [173]	validation_0-rmse:5.19199	validation_0-root_mean_squared_error:5.19199
# [174]	validation_0-rmse:5.19026	validation_0-root_mean_squared_error:5.19026
# [175]	validation_0-rmse:5.18935	validation_0-root_mean_squared_error:5.18935
# [176]	validation_0-rmse:5.18762	validation_0-root_mean_squared_error:5.18762
# [177]	validation_0-rmse:5.18582	validation_0-root_mean_squared_error:5.18582
# [178]	validation_0-rmse:5.18332	validation_0-root_mean_squared_error:5.18332
# [179]	validation_0-rmse:5.18229	validation_0-root_mean_squared_error:5.18229
# [180]	validation_0-rmse:5.18143	validation_0-root_mean_squared_error:5.18143
# [181]	validation_0-rmse:5.18057	validation_0-root_mean_squared_error:5.18057
# [182]	validation_0-rmse:5.17963	validation_0-root_mean_squared_error:5.17963
# [183]	validation_0-rmse:5.17909	validation_0-root_mean_squared_error:5.17909
# [184]	validation_0-rmse:5.17817	validation_0-root_mean_squared_error:5.17817
# [185]	validation_0-rmse:5.17631	validation_0-root_mean_squared_error:5.17631
# [186]	validation_0-rmse:5.17548	validation_0-root_mean_squared_error:5.17548
# [187]	validation_0-rmse:5.17475	validation_0-root_mean_squared_error:5.17475
# [188]	validation_0-rmse:5.17314	validation_0-root_mean_squared_error:5.17314
# [189]	validation_0-rmse:5.17273	validation_0-root_mean_squared_error:5.17273
# [190]	validation_0-rmse:5.17147	validation_0-root_mean_squared_error:5.17147
# [191]	validation_0-rmse:5.16945	validation_0-root_mean_squared_error:5.16945
# [192]	validation_0-rmse:5.16735	validation_0-root_mean_squared_error:5.16735
# [193]	validation_0-rmse:5.16646	validation_0-root_mean_squared_error:5.16646
# [194]	validation_0-rmse:5.16567	validation_0-root_mean_squared_error:5.16567
# [195]	validation_0-rmse:5.16387	validation_0-root_mean_squared_error:5.16387
# [196]	validation_0-rmse:5.16268	validation_0-root_mean_squared_error:5.16268
# [197]	validation_0-rmse:5.16131	validation_0-root_mean_squared_error:5.16131
# [198]	validation_0-rmse:5.15997	validation_0-root_mean_squared_error:5.15997
# [199]	validation_0-rmse:5.15932	validation_0-root_mean_squared_error:5.15932
# [200]	validation_0-rmse:5.15786	validation_0-root_mean_squared_error:5.15786
# [201]	validation_0-rmse:5.15718	validation_0-root_mean_squared_error:5.15718
# [202]	validation_0-rmse:5.15598	validation_0-root_mean_squared_error:5.15597
# [203]	validation_0-rmse:5.15487	validation_0-root_mean_squared_error:5.15487
# [204]	validation_0-rmse:5.15292	validation_0-root_mean_squared_error:5.15292
# [205]	validation_0-rmse:5.15236	validation_0-root_mean_squared_error:5.15236
# [206]	validation_0-rmse:5.15130	validation_0-root_mean_squared_error:5.15130
# [207]	validation_0-rmse:5.15057	validation_0-root_mean_squared_error:5.15057
# [208]	validation_0-rmse:5.14954	validation_0-root_mean_squared_error:5.14954
# [209]	validation_0-rmse:5.14911	validation_0-root_mean_squared_error:5.14911
# [210]	validation_0-rmse:5.14867	validation_0-root_mean_squared_error:5.14866
# [211]	validation_0-rmse:5.14797	validation_0-root_mean_squared_error:5.14797
# [212]	validation_0-rmse:5.14755	validation_0-root_mean_squared_error:5.14755
# [213]	validation_0-rmse:5.14698	validation_0-root_mean_squared_error:5.14698
# [214]	validation_0-rmse:5.14668	validation_0-root_mean_squared_error:5.14668
# [215]	validation_0-rmse:5.14628	validation_0-root_mean_squared_error:5.14628
# [216]	validation_0-rmse:5.14570	validation_0-root_mean_squared_error:5.14570
# [217]	validation_0-rmse:5.14520	validation_0-root_mean_squared_error:5.14520
# [218]	validation_0-rmse:5.14410	validation_0-root_mean_squared_error:5.14410
# [219]	validation_0-rmse:5.14114	validation_0-root_mean_squared_error:5.14114
# [220]	validation_0-rmse:5.13996	validation_0-root_mean_squared_error:5.13996
# [221]	validation_0-rmse:5.13972	validation_0-root_mean_squared_error:5.13972
# [222]	validation_0-rmse:5.13883	validation_0-root_mean_squared_error:5.13883
# [223]	validation_0-rmse:5.13824	validation_0-root_mean_squared_error:5.13825
# [224]	validation_0-rmse:5.13764	validation_0-root_mean_squared_error:5.13764
# [225]	validation_0-rmse:5.13735	validation_0-root_mean_squared_error:5.13735
# [226]	validation_0-rmse:5.13658	validation_0-root_mean_squared_error:5.13657
# [227]	validation_0-rmse:5.13628	validation_0-root_mean_squared_error:5.13628
# [228]	validation_0-rmse:5.13507	validation_0-root_mean_squared_error:5.13507
# [229]	validation_0-rmse:5.13482	validation_0-root_mean_squared_error:5.13482
# [230]	validation_0-rmse:5.13393	validation_0-root_mean_squared_error:5.13393
# [231]	validation_0-rmse:5.13344	validation_0-root_mean_squared_error:5.13344
# [232]	validation_0-rmse:5.13304	validation_0-root_mean_squared_error:5.13304
# [233]	validation_0-rmse:5.13265	validation_0-root_mean_squared_error:5.13265
# [234]	validation_0-rmse:5.13240	validation_0-root_mean_squared_error:5.13240
# [235]	validation_0-rmse:5.13213	validation_0-root_mean_squared_error:5.13213
# [236]	validation_0-rmse:5.13147	validation_0-root_mean_squared_error:5.13147
# [237]	validation_0-rmse:5.13107	validation_0-root_mean_squared_error:5.13107
# [238]	validation_0-rmse:5.13053	validation_0-root_mean_squared_error:5.13053
# [239]	validation_0-rmse:5.12945	validation_0-root_mean_squared_error:5.12945
# [240]	validation_0-rmse:5.12911	validation_0-root_mean_squared_error:5.12911
# [241]	validation_0-rmse:5.12853	validation_0-root_mean_squared_error:5.12853
# [242]	validation_0-rmse:5.12823	validation_0-root_mean_squared_error:5.12823
# [243]	validation_0-rmse:5.12793	validation_0-root_mean_squared_error:5.12793
# [244]	validation_0-rmse:5.12747	validation_0-root_mean_squared_error:5.12747
# [245]	validation_0-rmse:5.12720	validation_0-root_mean_squared_error:5.12720
# [246]	validation_0-rmse:5.12661	validation_0-root_mean_squared_error:5.12661
# [247]	validation_0-rmse:5.12623	validation_0-root_mean_squared_error:5.12623
# [248]	validation_0-rmse:5.12589	validation_0-root_mean_squared_error:5.12589
# [249]	validation_0-rmse:5.12562	validation_0-root_mean_squared_error:5.12562
# [250]	validation_0-rmse:5.12479	validation_0-root_mean_squared_error:5.12479
# [251]	validation_0-rmse:5.12405	validation_0-root_mean_squared_error:5.12405
# [252]	validation_0-rmse:5.12364	validation_0-root_mean_squared_error:5.12364
# [253]	validation_0-rmse:5.12290	validation_0-root_mean_squared_error:5.12289
# [254]	validation_0-rmse:5.12212	validation_0-root_mean_squared_error:5.12212
# [255]	validation_0-rmse:5.12148	validation_0-root_mean_squared_error:5.12148
# [256]	validation_0-rmse:5.12104	validation_0-root_mean_squared_error:5.12104
# [257]	validation_0-rmse:5.12073	validation_0-root_mean_squared_error:5.12073
# [258]	validation_0-rmse:5.12001	validation_0-root_mean_squared_error:5.12001
# [259]	validation_0-rmse:5.11970	validation_0-root_mean_squared_error:5.11970
# [260]	validation_0-rmse:5.11931	validation_0-root_mean_squared_error:5.11931
# [261]	validation_0-rmse:5.11902	validation_0-root_mean_squared_error:5.11902
# [262]	validation_0-rmse:5.11856	validation_0-root_mean_squared_error:5.11856
# train finish
# predict finish
# 100%|██████████| 10/10 [17:38<00:00, 105.84s/trial, best loss: 5.279327576557532]

# %%
# Now apply the best parameters in a model and save it, using autolog
print(best_estimator)

espacio = {
    'n_estimators': 150,
    'max_depth': 14,
    'learning_rate': 0.6841148295731673,
    'subsample': 0.6792524708491178,
    'colsample_bytree': 0.89215565512306,
    'random_state': 40,
    'n_jobs': 12,
    'eval_metric' : root_mean_squared_error,
    'early_stopping_rounds' : 5,
}

mlflow.xgboost.autolog(disable=False) 

with mlflow.start_run():
    mlflow.set_tag("developer", "Jhonattan")
    mlflow.set_tag("model", "xgboost_autolog")
    # mlflow.log_params(espacio) #Not necessary when autolog enabled
    model = xgboost.XGBRegressor(**espacio)
    print("train start")
    model.fit(X_train,y_train, eval_set=[(X_val_2, y_val_2)])
    print("train finish")
    y_pred = model.predict(X_val_2)
    print("predict finish")
    error = root_mean_squared_error(y_pred,y_val_2)
    mlflow.log_metric("rmse",error)
# Out:
# {'colsample_bytree': 0.89215565512306, 'learning_rate': 0.6841148295731673, 'max_depth': 8, 'n_estimators': 140, 'subsample': 0.6792524708491178}
# train start
# [0]	validation_0-rmse:8.24286	validation_0-root_mean_squared_error:8.24286
# [1]	validation_0-rmse:7.91777	validation_0-root_mean_squared_error:7.91777
# [2]	validation_0-rmse:7.67222	validation_0-root_mean_squared_error:7.67222
# [3]	validation_0-rmse:7.54827	validation_0-root_mean_squared_error:7.54827
# [4]	validation_0-rmse:7.37122	validation_0-root_mean_squared_error:7.37122
# [5]	validation_0-rmse:7.30401	validation_0-root_mean_squared_error:7.30402
# [6]	validation_0-rmse:7.24105	validation_0-root_mean_squared_error:7.24105
# [7]	validation_0-rmse:7.14162	validation_0-root_mean_squared_error:7.14162
# [8]	validation_0-rmse:7.09791	validation_0-root_mean_squared_error:7.09791
# [9]	validation_0-rmse:7.00303	validation_0-root_mean_squared_error:7.00303
# [10]	validation_0-rmse:6.91394	validation_0-root_mean_squared_error:6.91394
# [11]	validation_0-rmse:6.89716	validation_0-root_mean_squared_error:6.89716
# [12]	validation_0-rmse:6.86996	validation_0-root_mean_squared_error:6.86996
# [13]	validation_0-rmse:6.84606	validation_0-root_mean_squared_error:6.84605
# [14]	validation_0-rmse:6.80649	validation_0-root_mean_squared_error:6.80649
# [15]	validation_0-rmse:6.76422	validation_0-root_mean_squared_error:6.76422
# [16]	validation_0-rmse:6.72964	validation_0-root_mean_squared_error:6.72964
# [17]	validation_0-rmse:6.71457	validation_0-root_mean_squared_error:6.71457
# [18]	validation_0-rmse:6.70303	validation_0-root_mean_squared_error:6.70303
# [19]	validation_0-rmse:6.68743	validation_0-root_mean_squared_error:6.68743
# [20]	validation_0-rmse:6.66431	validation_0-root_mean_squared_error:6.66432
# [21]	validation_0-rmse:6.60111	validation_0-root_mean_squared_error:6.60111
# [22]	validation_0-rmse:6.54661	validation_0-root_mean_squared_error:6.54661
# [23]	validation_0-rmse:6.49874	validation_0-root_mean_squared_error:6.49874
# [24]	validation_0-rmse:6.45125	validation_0-root_mean_squared_error:6.45125
# [25]	validation_0-rmse:6.43412	validation_0-root_mean_squared_error:6.43412
# [26]	validation_0-rmse:6.42631	validation_0-root_mean_squared_error:6.42631
# [27]	validation_0-rmse:6.41028	validation_0-root_mean_squared_error:6.41028
# [28]	validation_0-rmse:6.39837	validation_0-root_mean_squared_error:6.39837
# [29]	validation_0-rmse:6.33731	validation_0-root_mean_squared_error:6.33731
# [30]	validation_0-rmse:6.33273	validation_0-root_mean_squared_error:6.33273
# [31]	validation_0-rmse:6.31948	validation_0-root_mean_squared_error:6.31948
# [32]	validation_0-rmse:6.29384	validation_0-root_mean_squared_error:6.29385
# [33]	validation_0-rmse:6.27949	validation_0-root_mean_squared_error:6.27949
# [34]	validation_0-rmse:6.24888	validation_0-root_mean_squared_error:6.24888
# [35]	validation_0-rmse:6.22790	validation_0-root_mean_squared_error:6.22790
# [36]	validation_0-rmse:6.21478	validation_0-root_mean_squared_error:6.21478
# [37]	validation_0-rmse:6.19044	validation_0-root_mean_squared_error:6.19045
# [38]	validation_0-rmse:6.18566	validation_0-root_mean_squared_error:6.18566
# [39]	validation_0-rmse:6.17897	validation_0-root_mean_squared_error:6.17897
# [40]	validation_0-rmse:6.13416	validation_0-root_mean_squared_error:6.13416
# [41]	validation_0-rmse:6.12891	validation_0-root_mean_squared_error:6.12891
# [42]	validation_0-rmse:6.08964	validation_0-root_mean_squared_error:6.08964
# [43]	validation_0-rmse:6.03848	validation_0-root_mean_squared_error:6.03848
# [44]	validation_0-rmse:5.98987	validation_0-root_mean_squared_error:5.98987
# [45]	validation_0-rmse:5.94142	validation_0-root_mean_squared_error:5.94142
# [46]	validation_0-rmse:5.90285	validation_0-root_mean_squared_error:5.90285
# [47]	validation_0-rmse:5.87383	validation_0-root_mean_squared_error:5.87383
# [48]	validation_0-rmse:5.83802	validation_0-root_mean_squared_error:5.83802
# [49]	validation_0-rmse:5.81589	validation_0-root_mean_squared_error:5.81589
# [50]	validation_0-rmse:5.80092	validation_0-root_mean_squared_error:5.80092
# [51]	validation_0-rmse:5.79225	validation_0-root_mean_squared_error:5.79225
# [52]	validation_0-rmse:5.78295	validation_0-root_mean_squared_error:5.78295
# [53]	validation_0-rmse:5.75043	validation_0-root_mean_squared_error:5.75043
# [54]	validation_0-rmse:5.72688	validation_0-root_mean_squared_error:5.72688
# [55]	validation_0-rmse:5.71039	validation_0-root_mean_squared_error:5.71039
# [56]	validation_0-rmse:5.70121	validation_0-root_mean_squared_error:5.70120
# [57]	validation_0-rmse:5.69769	validation_0-root_mean_squared_error:5.69769
# [58]	validation_0-rmse:5.69448	validation_0-root_mean_squared_error:5.69448
# [59]	validation_0-rmse:5.69109	validation_0-root_mean_squared_error:5.69109
# [60]	validation_0-rmse:5.67334	validation_0-root_mean_squared_error:5.67334
# [61]	validation_0-rmse:5.66384	validation_0-root_mean_squared_error:5.66385
# [62]	validation_0-rmse:5.65833	validation_0-root_mean_squared_error:5.65833
# [63]	validation_0-rmse:5.65232	validation_0-root_mean_squared_error:5.65232
# [64]	validation_0-rmse:5.64580	validation_0-root_mean_squared_error:5.64580
# [65]	validation_0-rmse:5.64418	validation_0-root_mean_squared_error:5.64418
# [66]	validation_0-rmse:5.63888	validation_0-root_mean_squared_error:5.63888
# [67]	validation_0-rmse:5.62233	validation_0-root_mean_squared_error:5.62233
# [68]	validation_0-rmse:5.60878	validation_0-root_mean_squared_error:5.60878
# [69]	validation_0-rmse:5.60574	validation_0-root_mean_squared_error:5.60574
# [70]	validation_0-rmse:5.60058	validation_0-root_mean_squared_error:5.60058
# [71]	validation_0-rmse:5.58779	validation_0-root_mean_squared_error:5.58779
# [72]	validation_0-rmse:5.58396	validation_0-root_mean_squared_error:5.58396
# [73]	validation_0-rmse:5.56602	validation_0-root_mean_squared_error:5.56602
# [74]	validation_0-rmse:5.56232	validation_0-root_mean_squared_error:5.56232
# [75]	validation_0-rmse:5.55351	validation_0-root_mean_squared_error:5.55351
# [76]	validation_0-rmse:5.54681	validation_0-root_mean_squared_error:5.54681
# [77]	validation_0-rmse:5.53837	validation_0-root_mean_squared_error:5.53837
# [78]	validation_0-rmse:5.53157	validation_0-root_mean_squared_error:5.53157
# [79]	validation_0-rmse:5.53097	validation_0-root_mean_squared_error:5.53097
# [80]	validation_0-rmse:5.52408	validation_0-root_mean_squared_error:5.52408
# [81]	validation_0-rmse:5.52076	validation_0-root_mean_squared_error:5.52076
# [82]	validation_0-rmse:5.51889	validation_0-root_mean_squared_error:5.51889
# [83]	validation_0-rmse:5.51706	validation_0-root_mean_squared_error:5.51706
# [84]	validation_0-rmse:5.51679	validation_0-root_mean_squared_error:5.51678
# [85]	validation_0-rmse:5.51466	validation_0-root_mean_squared_error:5.51466
# [86]	validation_0-rmse:5.51427	validation_0-root_mean_squared_error:5.51427
# [87]	validation_0-rmse:5.51266	validation_0-root_mean_squared_error:5.51266
# [88]	validation_0-rmse:5.51031	validation_0-root_mean_squared_error:5.51031
# [89]	validation_0-rmse:5.50907	validation_0-root_mean_squared_error:5.50907
# [90]	validation_0-rmse:5.50815	validation_0-root_mean_squared_error:5.50815
# [91]	validation_0-rmse:5.50704	validation_0-root_mean_squared_error:5.50705
# [92]	validation_0-rmse:5.50583	validation_0-root_mean_squared_error:5.50583
# [93]	validation_0-rmse:5.50314	validation_0-root_mean_squared_error:5.50314
# [94]	validation_0-rmse:5.50269	validation_0-root_mean_squared_error:5.50269
# [95]	validation_0-rmse:5.49905	validation_0-root_mean_squared_error:5.49905
# [96]	validation_0-rmse:5.49840	validation_0-root_mean_squared_error:5.49840
# [97]	validation_0-rmse:5.49628	validation_0-root_mean_squared_error:5.49628
# [98]	validation_0-rmse:5.49570	validation_0-root_mean_squared_error:5.49570
# [99]	validation_0-rmse:5.49531	validation_0-root_mean_squared_error:5.49531
# [100]	validation_0-rmse:5.49480	validation_0-root_mean_squared_error:5.49480
# [101]	validation_0-rmse:5.48932	validation_0-root_mean_squared_error:5.48932
# [102]	validation_0-rmse:5.48764	validation_0-root_mean_squared_error:5.48764
# [103]	validation_0-rmse:5.48358	validation_0-root_mean_squared_error:5.48358
# [104]	validation_0-rmse:5.47701	validation_0-root_mean_squared_error:5.47701
# [105]	validation_0-rmse:5.46999	validation_0-root_mean_squared_error:5.46999
# [106]	validation_0-rmse:5.46654	validation_0-root_mean_squared_error:5.46654
# [107]	validation_0-rmse:5.46280	validation_0-root_mean_squared_error:5.46279
# [108]	validation_0-rmse:5.46252	validation_0-root_mean_squared_error:5.46252
# [109]	validation_0-rmse:5.46029	validation_0-root_mean_squared_error:5.46029
# [110]	validation_0-rmse:5.45909	validation_0-root_mean_squared_error:5.45909
# [111]	validation_0-rmse:5.45882	validation_0-root_mean_squared_error:5.45882
# [112]	validation_0-rmse:5.45756	validation_0-root_mean_squared_error:5.45756
# [113]	validation_0-rmse:5.45622	validation_0-root_mean_squared_error:5.45621
# [114]	validation_0-rmse:5.45585	validation_0-root_mean_squared_error:5.45585
# [115]	validation_0-rmse:5.45470	validation_0-root_mean_squared_error:5.45470
# [116]	validation_0-rmse:5.45266	validation_0-root_mean_squared_error:5.45266
# [117]	validation_0-rmse:5.45184	validation_0-root_mean_squared_error:5.45184
# [118]	validation_0-rmse:5.45146	validation_0-root_mean_squared_error:5.45146
# [119]	validation_0-rmse:5.45117	validation_0-root_mean_squared_error:5.45117
# [120]	validation_0-rmse:5.44898	validation_0-root_mean_squared_error:5.44898
# [121]	validation_0-rmse:5.44688	validation_0-root_mean_squared_error:5.44688
# [122]	validation_0-rmse:5.44586	validation_0-root_mean_squared_error:5.44586
# [123]	validation_0-rmse:5.44595	validation_0-root_mean_squared_error:5.44595
# [124]	validation_0-rmse:5.44171	validation_0-root_mean_squared_error:5.44171
# [125]	validation_0-rmse:5.43847	validation_0-root_mean_squared_error:5.43847
# [126]	validation_0-rmse:5.43388	validation_0-root_mean_squared_error:5.43388
# [127]	validation_0-rmse:5.43286	validation_0-root_mean_squared_error:5.43286
# [128]	validation_0-rmse:5.43167	validation_0-root_mean_squared_error:5.43167
# [129]	validation_0-rmse:5.43117	validation_0-root_mean_squared_error:5.43117
# [130]	validation_0-rmse:5.42784	validation_0-root_mean_squared_error:5.42783
# [131]	validation_0-rmse:5.42547	validation_0-root_mean_squared_error:5.42547
# [132]	validation_0-rmse:5.42211	validation_0-root_mean_squared_error:5.42211
# [133]	validation_0-rmse:5.41945	validation_0-root_mean_squared_error:5.41945
# [134]	validation_0-rmse:5.41910	validation_0-root_mean_squared_error:5.41910
# [135]	validation_0-rmse:5.41729	validation_0-root_mean_squared_error:5.41729
# [136]	validation_0-rmse:5.41587	validation_0-root_mean_squared_error:5.41587
# [137]	validation_0-rmse:5.41261	validation_0-root_mean_squared_error:5.41261
# [138]	validation_0-rmse:5.41189	validation_0-root_mean_squared_error:5.41189
# [139]	validation_0-rmse:5.40841	validation_0-root_mean_squared_error:5.40841
# [140]	validation_0-rmse:5.40795	validation_0-root_mean_squared_error:5.40795
# [141]	validation_0-rmse:5.40748	validation_0-root_mean_squared_error:5.40748
# [142]	validation_0-rmse:5.40651	validation_0-root_mean_squared_error:5.40651
# [143]	validation_0-rmse:5.40555	validation_0-root_mean_squared_error:5.40555
# [144]	validation_0-rmse:5.40413	validation_0-root_mean_squared_error:5.40413
# [145]	validation_0-rmse:5.40348	validation_0-root_mean_squared_error:5.40348
# [146]	validation_0-rmse:5.40116	validation_0-root_mean_squared_error:5.40116
# [147]	validation_0-rmse:5.39978	validation_0-root_mean_squared_error:5.39978
# [148]	validation_0-rmse:5.39863	validation_0-root_mean_squared_error:5.39863
# [149]	validation_0-rmse:5.39805	validation_0-root_mean_squared_error:5.39805
# 2024/06/02 21:59:19 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\xgboost\core.py:160: UserWarning: [21:59:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# 2024/06/02 21:59:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\_distutils_hack\__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2024/06/02 21:59:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\_distutils_hack\__init__.py:26: UserWarning: Setuptools is replacing distutils."
# 2024/06/02 21:59:23 WARNING mlflow.utils.validation: Tag value '[{"run_id": "d3ebe367cab24a66aed95d2d39eae3fb", "artifact_path": "model", "utc_time_created": "2024-...' (39629 characters) is truncated to 5000 characters to meet the length limit.
# train finish
# predict finish

# %% [markdown]
# ## 0.4 Load a model from artifacts

# %%
model_path='runs:/d3ebe367cab24a66aed95d2d39eae3fb/model'
loaded_model = mlflow.xgboost.load_model(model_path)

# %% [markdown]
# ## 0.5 - Delete everything

# %%
del model
del alpha
del rmse
del X_train
del X_val
del X_val_2
del y_train
del y_val
del y_val_2
del y_pred
del best_estimator
del espacio
del trials_
del loaded_model

# %% [markdown]
# ## 0.6 - Interacting with MLflow client

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
# List all available experiments
client.search_experiments()
# Out:
# [<Experiment: artifact_location=('file:///c:/Users/jhorea/OneDrive - Ecopetrol '
#   'S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/1'), creation_time=1716771880869, experiment_id='1', last_update_time=1716771880869, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>,
#  <Experiment: artifact_location=('file:///c:/Users/jhorea/OneDrive - Ecopetrol '
#   'S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/0'), creation_time=1716771880862, experiment_id='0', last_update_time=1716771880862, lifecycle_stage='active', name='Default', tags={}>]

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids='1',
    filter_string="metrics.rmse < 5.5",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=10,
    order_by=["metrics.rmse ASC"]
)

for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id: 2d2a44df7541452cb9aea0580c717020, rmse: 5.2793
# run id: dcb6fffc66c942cb9303fe96ab38f0b1, rmse: 5.2928
# run id: 36f3eb46ccaf4b0593e672918d99234e, rmse: 5.3532
# run id: 712d2444f4a94238b9645bc0fa2ba20c, rmse: 5.3679
# run id: d3ebe367cab24a66aed95d2d39eae3fb, rmse: 5.3980
# run id: 71732e7e52a642c0b98ae21bdef06c3d, rmse: 5.4312
# run id: a4e5d6fe9025451d891ec9f788cf01eb, rmse: 5.4448

# %%
# Promoting a model to the registry

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

run_id = "2d2a44df7541452cb9aea0580c717020"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-regressor")
# Out:
# Registered model 'nyc-regressor' already exists. Creating a new version of this model...
# Created version '2' of model 'nyc-regressor'.
# <ModelVersion: aliases=[], creation_timestamp=1717459722327, current_stage='None', description=None, last_updated_timestamp=1717459722327, name='nyc-regressor', run_id='2d2a44df7541452cb9aea0580c717020', run_link=None, source=('file:///c:/Users/jhorea/OneDrive - Ecopetrol '
#  'S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/1/2d2a44df7541452cb9aea0580c717020/artifacts/model'), status='READY', status_message=None, tags={}, user_id=None, version=2>

# %%
model_name = "nyc-regressor"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 2, stage: None
# C:\Users\jhorea\AppData\Local\Temp\ipykernel_34372\2013026775.py:2: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.0/model-registry.html#migrating-from-stages
#   latest_versions = client.get_latest_versions(name=model_name)

# %%
model_version = 2
new_stage = "Staging"

from datetime import datetime
date = datetime.today().date()

client.update_model_version(
    name=model_name,
    version=model_version,
    description=f"The model version {model_version} was transitioned to {new_stage} on {date}"
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1717459722327, current_stage='Staging', description='The model version 2 was transitioned to Staging on 2024-06-03', last_updated_timestamp=1717460094861, name='nyc-regressor', run_id='2d2a44df7541452cb9aea0580c717020', run_link=None, source=('file:///c:/Users/jhorea/OneDrive - Ecopetrol '
#  'S.A/Documentos/mlops_zoomcamp_2024/2w_exp_tracking/mlruns/1/2d2a44df7541452cb9aea0580c717020/artifacts/model'), status='READY', status_message=None, tags={}, user_id=None, version=2>

# %% [markdown]
# # Homework development

# %% [markdown]
# ## Q1 - Install mlflow - whats the version i have?

# %%
# !pip install mlflow

# %%
# !mlflow --version
# Out:
# mlflow, version 2.13.0

# %% [markdown]
# Response: My mlflow version is 2.13.0

# %% [markdown]
# ## Q2 -- Download and preprocess the data -- How many files were saved to output folder?

# %%
# !python scripts/preprocess_data.py --raw_data_path ./taxi_data_folder --dest_path ./output_folder

# %%
os.listdir('./output_folder')
# Out:
# ['dv.pkl', 'test.pkl', 'train.pkl', 'val.pkl']

# %% [markdown]
# Response = The number of files are 4

# %% [markdown]
# ## Q3. Train a model with autolog - What is the value of the `min_samples_split` parameter:

# %%
# !python scripts/train.py --data_path ./output_folder
# Out:
# 2024/06/02 22:25:54 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/06/02 22:25:54 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/06/02 22:25:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/06/02 22:26:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\_distutils_hack\__init__.py:26: UserWarning: Setuptools is replacing distutils."
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# Response: Min_samples_split has a value of 2

# %% [markdown]
# ## Q4 - Launch the tracking server locally -

# %% [markdown]
# Response: default-artifact-root

# %% [markdown]
# ## Q5. Tune model hyperparameters - What's the best validation RMSE that you got?

# %%
# !python scripts/hpo.py --data_path ./output_folder

# %% [markdown]
# Response: Aprox 5.335

# %% [markdown]
# ## Q6. Promote the best model to the model registry

# %%
# !python scripts/register_model.py --data_path ./output_folder
# Out:
# 2024/06/03 22:01:20 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/06/03 22:01:21 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/06/03 22:01:26 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\_distutils_hack\__init__.py:26: UserWarning: Setuptools is replacing distutils."
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/06/03 22:01:29 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/06/03 22:01:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/06/03 22:01:51 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/06/03 22:02:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\jhorea\.conda\envs\mlops_zoomcamp\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Successfully registered model 'best-regressor'.
# Created version '1' of model 'best-regressor'.

# %% [markdown]
# response: The best test rmse is aprox 5.5674
